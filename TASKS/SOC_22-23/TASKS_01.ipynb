# %% [markdown]
# # Программирование на Python — задачи
#
# # Основные типы данных. Создание переменных. Основные ошибки.
#
# # Логический тип данных. Условные конструкции.
#
# *Автор: Паршина Анастасия, НИУ ВШЭ (tg: @aaparshina)*

# %% [markdown]
# ## 1
#
# Был исполнен следующий фрагмент кода, написанного на языке Python.
#
# `x = int(<ПРОПУСК>(input()))`
#
# Какую функцию стандартной библиотеки Python надо вписать на место пропуска, чтобы при вводе 0, в переменную x сохранялось целое число 1?

# %% [markdown]
# ## 2
#
# Впишите на место пропуска функцию стандартной библиотеки Python, чтобы команда
#
# `print(f'Права выдают в 18 лет, значит свои я могу получить через {18 - age} года')`
#
# вывела
#
# `Права выдают в 18 лет, значит свои я могу получить через 3 года`
#
# при вводе
#
# `15`
#
# `age = <ПРОПУСК>(input())`
#
# В ответе только название функции без дополнительных символов.

# %% [markdown]
# ## 3
#
# В переменных `a` и `b` хранятся некоторые числа. Напишите код, который бы менял значения переменных местами.

# %%
# до
a = 2
b = 5

# %%
# код

# %%
# после
print(a)
print(b)
# Out:
# 5
# 2

# %% [markdown]
# ## 4
#
# Был запущен следующий код
#
# ```x = input()
# if x == 0:
#     print('Введен ноль')
# elif x > 0:
#     print('Введено положительное число')
# else:
#     print('Введено отрицательное число')```
#
# Программа вывела ошибку `TypeError`. Какую строку кода нужно исправить, чтобы программа работала корректно?

# %% [markdown]
# ## 5
#
# Вы устраиваетесь на работу мечты! Чтобы вашу кандидатуру рассмотрели, необходимо набрать не менее 80-ти баллов за портфолио (переменная `port`) и ваш опыт работы должен составлять не менее 3-х лет (переменная `exp`).
#
# Какой оператор должен стоять на месте пропуска в логическом выражении, чтобы команда корректно проверяла, могут ли вас взять на работу?
#
# `(port >= 80)<ПРОПУСК>(exp >= 3)`

# %% [markdown]
# ## 6
#
# В переменных `price` и `delivery` хранятся положительные вещественные числа (цена товара и цена доставки этого товара соответственно).  В переменной `status` хранится целое число — 0 (товара нет в наличии) или 1 (товар есть в наличии).
#
# Витя купит товар только, если выполняются сразу оба условия:
#
# + товар есть в наличии;
# + суммарная цена товара и доставки не превышает 5000.
#
# Выберите логическое выражение, которое проверит — может Витя купить товар или нет.
#
# 1. `(status == 1) or (price + delivery < 5000)`
#
# 2. `(status == 1) and (price < 5000 and delivery < 5000)`
#
# 3. `(status == 0) and (price < 5000 and delivery < 5000)`
#
# 4. `(status == 1) and (price + delivery < 5000)`

# %% [markdown]
# ## 7
#
# Реализуйте следующую программу:
#
# + В переменную `X` считывается целое число.
# + Далее выполняется проверка на четность числа `X`. Если `X` — четное число, то программа выводит фразу "Число четное", в остальных случаях программа печатает "Число нечетное".

# %%
# код

# %% [markdown]
# ## 8
#
# Реализуйте следующую программу:
#
# + В переменную `temperature` считывается температура тела человека.
# + Если температура выше или ниже значения 36.6, то программа советуют обратиться к врачу и выводит фразу "Лучше записаться на прием у врача".
# + В остальных случаях программа пишет — "Все хорошо, можно идти на пары".

# %%
# код

# %% [markdown]
# ## 9
#
# В магазине проходит акция:
#
# + На все товары дороже 5000 рублей скидка 25%
# + На все товары дороже 1000, но дешевле 5000 рублей скидка 20%
# + На все товары дешевле 1000 рублей скидка 15%
#
# Реализуйте следующую программу:
#
# + В переменную price считывается цена товара.
# + Программа рассчитывает скидку на товар и пичатает ее.

# %%
# код

# %% [markdown]
# ## 10
#
# Реализуйте следующую программу:
#
# + В переменную `hour` считывается целое число (час дня).
# + Если время от 12 до 14 (включительно оба числа), то выводится фраза "Сейчас обед!", в остальных случаях выводится строка "Идем гулять".

# %%
# код

# %% [markdown]
# ## 11
#
# Вася решает, в какой город он может поехать. Известно, что за поездку от Москвы до Красногорска объем бензина в баке падает на 5 литров, а от Москвы до Истры на 10 литров.
#
# Программа работает следующим образом:
#
# + В переменную `petrol` считывается целое положительное число (сколько бензина сейчас заправлено, в литрах).
# + В переменную `destination` считывается строка — название города (Красногорск или Истра).
# + Программа проверяет, может ли автомобиль доехать до города:
#     + Если бензина хватит, то программа выводит фразу "Поездке быть!".
#     + В остальных случаях программа печатает "Нужно срочно на заправку!"

# %%
# код

# %% [markdown]
# ## 12
#
# У питона есть набор любимых чисел.
#
#     favorites = [3, 7, 11, 23, 18, 48, 81]
#
# Напишите программу, которая просит пользователя ввести целое число, и если оно нравится питону, на экран будет выводиться сообщение: "Мое любимое число!", если нет ‒ "Эх, ну почему?".

# %%
# код
